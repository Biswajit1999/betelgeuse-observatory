# %% [markdown]
# # ALMA 2023 integrated-continuum sanity check
# This elementary three-point fit is not the paper's spatially resolved, matched-beam spectral-index analysis.

# %%
from science.betelgeuse import fit_power_law
fit = fit_power_law([223.55, 337.99, 485.22], [0.28, 0.51, 0.90], [0.014, 0.04, 0.09])
fit

# %%
assert round(fit.spectral_index, 2) == 1.49
assert round(fit.spectral_index_sigma, 2) == 0.13
