# %% [markdown]
# # Long-term photometry
# Planned baseline-first workflow: provenance normalization, binning, Lomb-Scargle, time-frequency analysis, Gaussian process, change points, and orbital-phase overlay. No period is assumed to be a pulsation by default.
