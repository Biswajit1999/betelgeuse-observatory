# %% [markdown]
# # ML experiments
# Neural experiments begin only after a relevant transparent baseline. Required splits: temporal, whole-epoch, instrument, and simulation-family hold-outs. Forbidden target: an exploded/not-exploded label for the inaccessible remote state.
