# %% [markdown]
# # Distance and light-travel time
# Monte Carlo propagation for the asymmetric 172 +13/-11 pc posterior. The lifetime input is a scenario conditioned on the observed emitted state.

# %%
from science.betelgeuse import propagate_causality
summary = propagate_causality(2026, 300, samples=50_000, seed=172)
summary

# %%
assert abs(summary.arrival_year.median - 2326) < 1e-9
summary.emission_year, summary.collapse_coordinate_year, summary.arrival_year
