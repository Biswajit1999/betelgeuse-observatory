# %% [markdown]
# # Evolutionary scenarios
# Scenario A (400/416-day fundamental plus companion/LSP, core helium burning) and Scenario B (roughly 2200-day fundamental, late core-carbon burning) remain separate conditional model families.
