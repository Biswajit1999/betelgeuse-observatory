# %% [markdown]
# # Spectral laboratory
# Planned reproducible workflow: rest-frame conversion, continuum subtraction, line metadata, centroid/FWHM/asymmetry, uncertainty, channel maps, and position-velocity diagrams. Calibrated archive products are required before analysis.
